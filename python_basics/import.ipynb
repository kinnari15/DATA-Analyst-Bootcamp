# %%
from package_custom.maths import addition 

addition(15,26)
# Out:
# 41

# %%
from package_custom import maths 

maths.addition(15,26)
# Out:
# 41

# %%
from package_custom import * 

print(addition(15,26))
print(subtraction(26,15))
# Out:
# 41
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 from package_custom import *
#       3 print(addition(15,26))
# ----> 4 print(subtraction(26,15))
#
# NameError: name 'subtraction' is not defined
