# %%
### Exception handling allows you to handle errors gracefully and take corrective actions without stopping the execution of program.

# %%
"""
1. ZeroDivisionError: Dividing by zero
2. TypeError: Trying to perform an operation on a non-numeric value
3. ValueError: Trying to perform an operation with an invalid value 
4. IndexError: Trying to access an index that does not exist in a list or string
5. KeyError: Trying to access a key that does not exist in a dictionary
6. AttributeError: Trying to access an attribute that does not exist in an object
7. SyntaxError: Error in the syntax of the code
8. NameError: Trying to use a variable that has not been defined

"""
# Out:
# '\n1. ZeroDivisionError: Dividing by zero\n2. TypeError: Trying to perform an operation on a non-numeric value\n3. ValueError: Trying to perform an operation with an invalid value \n4. IndexError: Trying to access an index that does not exist in a list or string\n5. KeyError: Trying to access a key that does not exist in a dictionary\n6. AttributeError: Trying to access an attribute that does not exist in an object\n7. SyntaxError: Error in the syntax of the code\n8. NameError: Trying to use a variable that has not been defined\n\n'

# %%
#a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
#### try, except block
"""
try:
    # code that might raise an exception
    #a = b 
except:
    # code to handle the exception
    print("The variable has not been assigned")
    """
# Out:
# The variable has not been assigned

# %%
"""

try:
    a=b 
except NameError as ex:
    print("Variable b is not defined") """
# Out:
# Variable b is not defined

# %%
#result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
except ZeroDivisionError as ex:
    print(f"An error occurred: {ex}")
# Out:
# An error occurred: division by zero

# %%
""" try:
    result = 1/2 
    a=b 
except ZeroDivisionError as ex:
    print("Error: ", ex)
except Exception as ex1:
    print("An error occurred: ", ex1)
    print('Main exception got caught here') """
# Out:
# An error occurred:  name 'b' is not defined
# Main exception got caught here

# %%
  #  num = int(input("Enter a number: "))
   # result = 10/num
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 num = int(input("Enter a number: "))
#       2 result = 10/num
#
# ValueError: invalid literal for int() with base 10: 'd'

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num 
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Invalid input. Please enter a valid number.

# %%
## try, except, else block 

try:
    num = int(input("Enter a number: "))
    result = 10/num 
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("Cannot divide by zero. Please enter a non-zero number.")
except Exception as ex:
    print(ex)
else:
    print(f'{result}')
# Out:
# 3.3333333333333335

# %%
# try, except, else and finally block 

try:
    num = int(input("Enter a number: "))
    result = 10/num 
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("Cannot divide by zero. Please enter a non-zero number.")
except Exception as ex:
    print(ex)
else:
    print(f'{result}')
finally:
    print("This will always be executed")         # This will always be executed, regardless of whether or not it is correct
# Out:
# 2.0
# This will always be executed

# %%
#### File handling and exception handling 

try:
    file = open('example1.txt','r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found")
except Exception as ex:
    print("An error occurred: ", str(ex))
finally:
    if 'file' in locals() and not file.closed():
        file.close()
        print("File closed")
# Out:
# File not found
