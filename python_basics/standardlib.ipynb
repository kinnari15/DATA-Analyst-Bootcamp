# %%
##library is a vast collection of modules and packages that come bundled with python

# %%
import array 

arr = array.array('i',[1,2,3,4])

# %%
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math 

math.sqrt(4)
# Out:
# 2.0

# %%
import random 

print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 9
# banana

# %%
## file and directory access 

import os 

print(os.getcwd())
# Out:
# c:\Users\kinnari\OneDrive\Desktop\Data_Analysis\Bootcamp\Python\python_basics

# %%
os.mkdir('test')

# %%
### high level operation on files and collections 

import shutil 

shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
### data serialization 

import json 

data = {
    "name": "John",
    "age": 30,
    "city": "New York"

}

json_str= json.dumps(data)
print(json_str)
type(json_str)

parsed_data = json.loads(json_str)    ##parsing is taking data of one format and converting it to another
print(parsed_data)
type(parsed_data)
# Out:
# {"name": "John", "age": 30, "city": "New York"}
# {'name': 'John', 'age': 30, 'city': 'New York'}
# dict

# %%
## csv 

import csv 

with open('example.csv',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name","Age","Country"])
    writer.writerow(["John","25","USA"])

with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'Country']
# ['John', '25', 'USA']

# %%
## datetime 

from datetime import datetime, timedelta 

now = datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-05-18 20:25:36.287856
# 2025-05-17 20:25:36.287856

# %%
## time 

import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1747580210.063183
# 1747580212.0639281

# %%
## regular expression 

import re 

pattern = r'\d+'
text = 'I have 26 apples and 15 oranges'
match = re.search(pattern,text)
print(match.group())
# Out:
# 26
