# %%
##modules and packages helps oraganize and reuse the code

# %%
import math 

math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt, pi 

print(sqrt(4))
print(sqrt(25))
print(pi)
# Out:
# 2.0
# 5.0
# 3.141592653589793

# %%
import numpy as np 

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *

sqrt(16)
pi
# Out:
# 3.141592653589793

# %%
#####creating your own package
