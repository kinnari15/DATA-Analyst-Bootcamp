# %%
from package_custom.maths import addition 

addition(15,26)
# Out:
# 41

# %%
from package_custom import maths 

maths.addition(15,26)
# Out:
# 41

# %%
from package_custom import maths

print(addition(15,26))
#print(maths.subsraction(26,15))
# Out:
# 41

# %%
from package_custom.maths import substraction

print(substraction(26,15))     ###restart the kernel - CTRL+SHIFT+P ---> Jupyter:Restart Kernel if the function is not getting imported
# Out:
# 11

# %%
from package_custom.subpackages.mult import multiply

print(multiply(26,15))
# Out:
# 390
